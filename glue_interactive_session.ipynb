# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
# %number_of_workers 2
# %idle_timeout 15
# %glue_version 2.0
# %number_of_workers 2
# Out:
# Previous number of workers: 2
# Setting new number of workers to: 2
# Current idle_timeout is 15 minutes.
# idle_timeout has been set to 15 minutes.
# Setting Glue version to: 2.0
# Previous number of workers: 2
# Setting new number of workers to: 2

# %%
from awsglue.context import GlueContext
from awsglue.job import Job
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext

sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
job = Job(glueContext)


osm_dataframe = glueContext.create_dynamic_frame.from_options(
    's3',
    {'paths':['s3://awsglue-datasets-hgrig/SF_CA_USA_edges.csv']},
    'csv',
    {'withHeader':'True'})
print("Count:", osm_dataframe.count())
osm_dataframe.printSchema()
# Out:
# Trying to create a Glue session for the kernel.
# Session Type: etl
# Worker Type: G.2X
# Number of Workers: 2
# Idle Timeout: 15
# Session ID: a54ef952-cf02-4946-80c8-32f22f6fdfb5
# Applying the following default arguments:
# --glue_kernel_version 1.0.7
# --enable-glue-datacatalog true
# Waiting for session a54ef952-cf02-4946-80c8-32f22f6fdfb5 to get into ready status...
# Session a54ef952-cf02-4946-80c8-32f22f6fdfb5 has been created.
# Count: 27427
# root
# |-- col0: string
# |-- col1: string
# |-- col2: string
# |-- col3: string
# |-- col4: string
# |-- col5: string
# |-- col6: string
# |-- col7: string
# |-- col8: string
# |-- col9: string
# |-- col10: string
# |-- col11: string
# |-- col12: string
# |-- col13: string
# |-- col14: string

# %%
# %status
# Out:
# Session ID: a54ef952-cf02-4946-80c8-32f22f6fdfb5
# Status: READY
# Role: arn:aws:iam::548097210593:role/glue_interactive_role
# CreatedOn: 2024-12-21 18:17:59.567000+04:00
# GlueVersion: 2.0
# Session Type: glueetl
# Idle Timeout: 15
# Timeout: 2880
# Tags: {'owner': 'AIDAX7HJDXDQWQC3EQX4A'}
# Worker Type: G.2X
# Number of Workers: 2
# Region: us-west-2
# Applying the following default arguments:
# --glue_kernel_version 1.0.7
# --enable-glue-datacatalog true
# Arguments Passed: ['--glue_kernel_version: 1.0.7', '--enable-glue-datacatalog: true']

# %%
# %stop_session
# Out:
# Stopping session: a54ef952-cf02-4946-80c8-32f22f6fdfb5
# Stopped session.
